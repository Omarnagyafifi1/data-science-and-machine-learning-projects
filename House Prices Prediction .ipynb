# %%
# import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# reading the data 
df=pd.read_csv(r"C:\Users\20120\Downloads\kc_house_data.csv")
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    floors  waterfront  view  condition  ...  yr_built  yr_renovated  zipcode  \
# 0     1.0           0     0          3  ...      1955             0    98178
# 1     2.0           0     0          3  ...      1951          1991    98125
# 2     1.0           0     0          3  ...      1933             0    98028
# 3     1.0           0     0          5  ...      1965             0    98136
# 4     1.0           0     0          3  ...      1987             0    98074
#
# ...

# %%
# drop id column
df.drop('id',axis=1,inplace=True)
df.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  floors  \
# 0  20141013T000000  221900.0         3       1.00         1180     1.0
# 1  20141209T000000  538000.0         3       2.25         2570     2.0
# 2  20150225T000000  180000.0         2       1.00          770     1.0
# 3  20141209T000000  604000.0         4       3.00         1960     1.0
# 4  20150218T000000  510000.0         3       2.00         1680     1.0
#
#    waterfront  view  condition  grade  yr_built  yr_renovated  zipcode  \
# 0           0     0          3      7      1955             0    98178
# 1           0     0          3      7      1951          1991    98125
# 2           0     0          3      6      1933             0    98028
# 3           0     0          5      7      1965             0    98136
# 4           0     0          3      8      1987             0    98074
#
#        lat     long  sqft_living15  sqft_lot15  sqft_lot  sqft_above  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21613 non-null  object
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  yr_built       21613 non-null  int64
#  11  yr_renovated   21613 non-null  int64
#  12  zipcode        21613 non-null  int64
#  13  lat            21613 non-null  float64
#  14  long           21613 non-null  float64
#  15  sqft_living15  21613 non-null  int64
#  16  sqft_lot15     21613 non-null  int64
# ...

# %%
# convert date column to datetime format
df['date']=pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21613 non-null  datetime64[ns]
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  yr_built       21613 non-null  int64
#  11  yr_renovated   21613 non-null  int64
#  12  zipcode        21613 non-null  int64
#  13  lat            21613 non-null  float64
#  14  long           21613 non-null  float64
#  15  sqft_living15  21613 non-null  int64
#  16  sqft_lot15     21613 non-null  int64
# ...

# %%
df.describe()
# Out:
#                                 date         price      bedrooms  \
# count                          21613  2.161300e+04  21613.000000
# mean   2014-10-29 04:38:01.959931648  5.401822e+05      3.370842
# min              2014-05-02 00:00:00  7.500000e+04      0.000000
# 25%              2014-07-22 00:00:00  3.219500e+05      3.000000
# 50%              2014-10-16 00:00:00  4.500000e+05      3.000000
# 75%              2015-02-17 00:00:00  6.450000e+05      4.000000
# max              2015-05-27 00:00:00  7.700000e+06     33.000000
# std                              NaN  3.673622e+05      0.930062
#
#           bathrooms   sqft_living        floors    waterfront          view  \
# count  21613.000000  21613.000000  21613.000000  21613.000000  21613.000000
# mean       2.114757   2079.899736      1.494309      0.007542      0.234303
# min        0.000000    290.000000      1.000000      0.000000      0.000000
# ...

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'yr_built', 'yr_renovated',
#        'zipcode', 'lat', 'long', 'sqft_living15', 'sqft_lot15', 'sqft_lot',
#        'sqft_above', 'sqft_basement'],
#       dtype='object')

# %%
df.drop(['zipcode', 'lat', 'long'], axis=1, inplace=True)
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0 2014-10-13  221900.0         3       1.00         1180     1.0           0
# 1 2014-12-09  538000.0         3       2.25         2570     2.0           0
# 2 2015-02-25  180000.0         2       1.00          770     1.0           0
# 3 2014-12-09  604000.0         4       3.00         1960     1.0           0
# 4 2015-02-18  510000.0         3       2.00         1680     1.0           0
#
#    view  condition  grade  yr_built  yr_renovated  sqft_living15  sqft_lot15  \
# 0     0          3      7      1955             0           1340        5650
# 1     0          3      7      1951          1991           1690        7639
# 2     0          3      6      1933             0           2720        8062
# 3     0          5      7      1965             0           1360        5000
# 4     0          3      8      1987             0           1800        7503
#
#    sqft_lot  sqft_above  sqft_basement
# ...

# %%
# check for missing values
df.isnull().sum()
# Out:
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# yr_built         0
# yr_renovated     0
# sqft_living15    0
# sqft_lot15       0
# sqft_lot         0
# sqft_above       0
# sqft_basement    0
# dtype: int64

# %%
df['age']=2025 - df['yr_built']
df.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  floors  waterfront  \
# 0 2014-10-13  221900.0         3       1.00         1180     1.0           0
# 1 2014-12-09  538000.0         3       2.25         2570     2.0           0
# 2 2015-02-25  180000.0         2       1.00          770     1.0           0
# 3 2014-12-09  604000.0         4       3.00         1960     1.0           0
# 4 2015-02-18  510000.0         3       2.00         1680     1.0           0
#
#    view  condition  grade  yr_built  yr_renovated  sqft_living15  sqft_lot15  \
# 0     0          3      7      1955             0           1340        5650
# 1     0          3      7      1951          1991           1690        7639
# 2     0          3      6      1933             0           2720        8062
# 3     0          5      7      1965             0           1360        5000
# 4     0          3      8      1987             0           1800        7503
#
# ...

# %%
# check for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.nunique()
# Out:
# date              372
# price            3625
# bedrooms           13
# bathrooms          30
# sqft_living      1038
# floors              6
# waterfront          2
# view                5
# condition           5
# grade              12
# yr_built          116
# yr_renovated       70
# sqft_living15     777
# sqft_lot15       8689
# sqft_lot         9782
# sqft_above        946
# sqft_basement     306
# age               116
# dtype: int64

# %%
cat_cols = []
num_cols = []
for col in df.columns:
    if df[col].dtype == 'object' or df[col].nunique() <= 30:
        cat_cols.append(col)
    else:
        num_cols.append(col)

# %%
print("Categorical Columns:", cat_cols)
print("Numerical Columns:", num_cols)
# Out:
# Categorical Columns: ['bedrooms', 'bathrooms', 'floors', 'waterfront', 'view', 'condition', 'grade']
# Numerical Columns: ['date', 'price', 'sqft_living', 'yr_built', 'yr_renovated', 'sqft_living15', 'sqft_lot15', 'sqft_lot', 'sqft_above', 'sqft_basement', 'age']

# %%
num_cols.remove('date')
num_cols.remove('yr_built')
num_cols.remove(
 'yr_renovated')

# %%
cat_cols.remove('bathrooms')

# %%
# convert date column to datatype
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           21613 non-null  datetime64[ns]
#  1   price          21613 non-null  float64
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   floors         21613 non-null  float64
#  6   waterfront     21613 non-null  int64
#  7   view           21613 non-null  int64
#  8   condition      21613 non-null  int64
#  9   grade          21613 non-null  int64
#  10  yr_built       21613 non-null  int64
#  11  yr_renovated   21613 non-null  int64
#  12  sqft_living15  21613 non-null  int64
#  13  sqft_lot15     21613 non-null  int64
#  14  sqft_lot       21613 non-null  int64
#  15  sqft_above     21613 non-null  int64
#  16  sqft_basement  21613 non-null  int64
# ...

# %% [markdown]
# # Data visualization

# %%
# histogram for price column
plt.figure(figsize=(10,6))
sns.histplot(df['price'], kde=True)     
plt.title('Distribution of House Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# histogram for price column using plotly
import plotly.express as px
fig = px.histogram(df, x='price', title='Distribution of House Prices')
fig.update_layout(xaxis_title='Price', yaxis_title='Frequency')
fig.show()

# %%
# make a boxplot for price column
plt.figure(figsize=(8,5))
px.box(x=df['price'], title='Boxplot of House Prices', labels={'x':'Price'})

# %%
plt.figure(figsize=(15, 10))

for i, col in enumerate(num_cols, 1):
    plt.subplot(4, 2, i)  
    sns.histplot(data=df, x=col, kde=True, bins=50)  
    plt.title(f'Distribution of {col}')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 10))

for i, col in enumerate(num_cols, 1):
    plt.subplot(4, 2, i)  
    sns.boxplot(data=df, x=col)  
    plt.title(f'Box Plot of {col}')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 10))

for i, col in enumerate(cat_cols, 1):
    plt.subplot(4, 2, i)  
    sns.countplot(data=df, x=col)  
    plt.title(f'Bar Plot of {col}')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15, 10))
plt.title('Bar Plot of Bathrooms')
sns.countplot(x='bathrooms', data=df)
plt.xlabel('bathsrooms')  
plt.ylabel('Count')
plt.show()

# %%
sns.pairplot(df[num_cols])

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()

# %% [markdown]
# # feature selection

# %%
df.columns
# Out:
# Index(['date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'floors',
#        'waterfront', 'view', 'condition', 'grade', 'yr_built', 'yr_renovated',
#        'sqft_living15', 'sqft_lot15', 'sqft_lot', 'sqft_above',
#        'sqft_basement', 'age'],
#       dtype='object')

# %%
df=df.drop('date',axis=1)
df.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  floors  waterfront  view  \
# 0  221900.0         3       1.00         1180     1.0           0     0
# 1  538000.0         3       2.25         2570     2.0           0     0
# 2  180000.0         2       1.00          770     1.0           0     0
# 3  604000.0         4       3.00         1960     1.0           0     0
# 4  510000.0         3       2.00         1680     1.0           0     0
#
#    condition  grade  yr_built  yr_renovated  sqft_living15  sqft_lot15  \
# 0          3      7      1955             0           1340        5650
# 1          3      7      1951          1991           1690        7639
# 2          3      6      1933             0           2720        8062
# 3          5      7      1965             0           1360        5000
# 4          3      8      1987             0           1800        7503
#
#    sqft_lot  sqft_above  sqft_basement  age
# 0      5650        1180              0   70
# ...

# %%
x=df.drop('price',axis=1)
y=df['price']

# %% [markdown]
# # Data preprocessing

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
from sklearn.preprocessing import StandardScaler

# Standardize the selected numerical columns
std = StandardScaler()
x_train_std = x_train.copy()
x_test_std = x_test.copy()

x_train_std[['sqft_living', 'sqft_basement']] = std.fit_transform(x_train[['sqft_living', 'sqft_basement']])
x_test_std[['sqft_living', 'sqft_basement']] = std.transform(x_test[['sqft_living', 'sqft_basement']])

      )
# Out:
# Mean Absolute Error: 141400.86396239072
# Mean Squared Error: 52824503139.64108
# Root Mean Squared Error: 229835.81779096375
# R^2 Score: 0.6470489763865505

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R^2 Score:", r2_score(y_test, y_pred))
# Out:
# Mean Absolute Error: 141400.8639623976
# Mean Squared Error: 52824503139.64368
# Root Mean Squared Error: 229835.8177909694
# R^2 Score: 0.6470489763865331

# %%
from sklearn.linear_model import Ridge, Lasso
ridge = Ridge(alpha=1.0)
ridge.fit(x_train, y_train)
y_pred_ridge = ridge.predict(x_test)
print("Ridge Regression")
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred_ridge))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred_ridge))  
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, y_pred_ridge)))
print("R^2 Score:", r2_score(y_test, y_pred_ridge))
lasso = Lasso(alpha=0.1)
lasso.fit(x_train, y_train)
y_pred_lasso = lasso.predict(x_test)
print("Lasso Regression")
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred_lasso))
print("Mean Squared Error:", mean_squared_error(y_test, y_pred_lasso))
print("Root Mean Squared Error:", np.sqrt(mean_squared_error(y_test, y_pred_lasso)))
print("R^2 Score:", r2_score(y_test, y_pred_lasso))
# Out:
# Ridge Regression
# Mean Absolute Error: 141405.58362457308
# Mean Squared Error: 52837121706.15258
# Root Mean Squared Error: 229863.2674138097
# R^2 Score: 0.6469646644536016
# Lasso Regression
# Mean Absolute Error: 141400.8756238213
# Mean Squared Error: 52824531694.04803
# Root Mean Squared Error: 229835.87991009591
# R^2 Score: 0.6470487855980611
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning:
#
# Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.753e+14, tolerance: 1.622e+11

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=200, random_state=42)
rf.fit(x_train, y_train)
y_pred_rf = rf.predict(x_test)

print("Random Forest R2:", r2_score(y_test, y_pred_rf))
print("Random Forest RMSE:", mean_squared_error(y_test, y_pred_rf, squared=False))
# Out:
# Random Forest R2: 0.7464328262651143
# Random Forest RMSE: 194808.09637923178
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning:
#
# 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr = GradientBoostingRegressor(n_estimators=200, learning_rate=0.1, random_state=42)
gbr.fit(x_train_std, y_train)
y_pred_gbr = gbr.predict(x_test_std)
print("Gradient Boosting R2:", r2_score(y_test, y_pred_gbr))
print("Gradient Boosting RMSE:", mean_squared_error(y_test, y_pred_gbr, squared=False))
# Out:
# Gradient Boosting R2: 0.7505121603860818
# Gradient Boosting RMSE: 193234.7273509544
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning:
#
# 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.

# %%
import xgboost as xgb
xgbr = xgb.XGBRegressor(n_estimators=200, learning_rate=0.1, random_state=42)
xgbr.fit(x_train_std, y_train)
y_pred_xgb = xgbr.predict(x_test_std)
print("XGBoost R2:", r2_score(y_test, y_pred_xgb))
print("XGBoost RMSE:", mean_squared_error(y_test, y_pred_xgb, squared=False))
# Out:
# XGBoost R2: 0.7157354784499246
# XGBoost RMSE: 206263.23144441022
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning:
#
# 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.

# %% [markdown]
# # the best model is GradientBoostingRegressor
